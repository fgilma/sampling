# %% [markdown]
# # Nivell 1
# #### Exercici 1
# Agafa un conjunt de dades de tema esportiu que t'agradi. Realitza un mostreig de les dades generant una mostra aleatòria simple i una mostra sistemàtica.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# **Dataset**
#
# He elegido un [dataset](https://datahub.io/sports-data/spanish-la-liga#data) de la Liga española de fútbol, temporada 20-21, los datos llegan hasta el 12-04-21

# %%
df=pd.read_csv('Desktop/DataScience/datasets/liga/SP1.csv')
df=df.iloc[:,3:26]
df.head()
# Out:
#      HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  AF  \
# 0       Eibar       Celta     0     0   D     0     0   D   8   6  ...  13
# 1     Granada  Ath Bilbao     2     0   H     0     0   D   4   9  ...  10
# 2       Cadiz     Osasuna     0     2   A     0     1   A  12   6  ...  21
# 3      Alaves       Betis     0     1   A     0     0   D   7  11  ...  17
# 4  Valladolid    Sociedad     1     1   D     1     0   H   8   8  ...  17
#
#    HC  AC  HY  AY  HR  AR  B365H  B365D  B365A
# 0   3   3   4   4   1   0   2.50   3.25   2.90
# 1   1   2   3   4   0   0   2.75   3.10   2.75
# 2   6   2   2   2   0   0   2.80   3.00   2.75
# 3   6   4   3   3   0   0   2.80   3.20   2.60
# 4   5   3   4   1   0   0   2.80   3.20   2.60
#
# [5 rows x 23 columns]

# %% [markdown]
# **Columnas:**
# 1. Div = League Division
# 2. Date = Match Date (dd/mm/yy)
# 3. Time = Time of match kick off
# 4. HomeTeam = Home Team
# 5. AwayTeam = Away Team
# 6. FTHG = Full Time Home Team Goals
# 7. FTAG = Full Time Away Team Goals
# 8. FTR  = Full Time Result (H=Home Win, D=Draw, A=Away Win)
# 9. HTHG = Half Time Home Team Goals
# 10. HTAG = Half Time Away Team Goals
# 11. HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
# 12. HS = Home Team Shots
# 13. AS = Away Team Shots
# 14. HST = Home Team Shots on Target
# 15. AST = Away Team Shots on Target
# 16. HF = Home Team Fouls Committed
# 17. AF = Away Team Fouls Committed
# 18. HC = Home Team Corners
# 19. AC = Away Team Corners
# 20. HY = Home Team Yellow Cards
# 21. AY = Away Team Yellow Cards
# 22. HR = Home Team Red Cards
# 23. AR = Away Team Red Cards
# 24. B365H = Bet365 home win odds
# 25. B365D = Bet365 draw odds
# 26. B365A = Bet365 away win odds

# %%
df.shape
# Out:
# (300, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 23 columns):
# HomeTeam    300 non-null object
# AwayTeam    300 non-null object
# FTHG        300 non-null int64
# FTAG        300 non-null int64
# FTR         300 non-null object
# HTHG        300 non-null int64
# HTAG        300 non-null int64
# HTR         300 non-null object
# HS          300 non-null int64
# AS          300 non-null int64
# HST         300 non-null int64
# AST         300 non-null int64
# HF          300 non-null int64
# AF          300 non-null int64
# HC          300 non-null int64
# AC          300 non-null int64
# HY          300 non-null int64
# AY          300 non-null int64
# HR          300 non-null int64
# AR          300 non-null int64
# B365H       300 non-null float64
# B365D       300 non-null float64
# B365A       300 non-null float64
# dtypes: float64(3), int64(16), object(4)
# memory usage: 54.0+ KB

# %% [markdown]
# **Muestra aleatoria simple**
#
# Seleccionamos aleatoriamente 10 muestras

# %%
seed=123
np.random.seed(123)
df.sample(10)
# Out:
#        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  AF  \
# 262     Osasuna   Valladolid     0     0   D     0     0   D  14  12  ...   9
# 114    Valencia   Ath Bilbao     2     2   D     1     0   H  11  13  ...  16
# 165  Ath Bilbao    Barcelona     2     3   A     1     2   A   8  13  ...   6
# 278  Ath Madrid       Alaves     1     0   H     0     0   D   8   9  ...  12
# 293       Eibar      Levante     0     1   A     0     1   A  10   6  ...   7
# 169     Osasuna  Real Madrid     0     0   D     0     0   D   8   9  ...   3
# 11        Betis   Valladolid     2     0   H     2     0   H  16   9  ...  10
# 235  Ath Bilbao   Villarreal     1     1   D     1     1   D  18   3  ...  12
# 240     Sevilla    Barcelona     0     2   A     0     1   A   4   9  ...   9
# 206     Levante      Granada     2     2   D     1     1   D  11  11  ...  13
#
#      HC  AC  HY  AY  HR  AR  B365H  B365D  B365A
# 262   7   3   2   3   0   0   2.20   3.10   3.60
# ...

# %% [markdown]
# **Muestra sistemática**
# Nuestra muestra tendrá 10 elementos y la población total es de 300 muestras. Seleccionamos al azar un número entre los 30 primeros elementos del dataframe y después le vamos sumando 30 repetidamente.

# %%
seed=123
np.random.seed(123)
start=np.random.randint(0,30)
start
# Out:
# 13

# %%
df.iloc[start::30]
# Out:
#        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  AF  \
# 13     Sociedad  Real Madrid     0     0   D     0     0   D   6  16  ...  12
# 43      Granada      Sevilla     1     0   H     0     0   D  13   8  ...  11
# 73        Elche        Celta     1     1   D     1     1   D   8  14  ...  12
# 103  Ath Bilbao        Celta     0     2   A     0     0   D  10   6  ...  15
# 133       Cadiz       Getafe     0     2   A     0     1   A   8   6  ...  22
# 163      Huesca    Barcelona     0     1   A     0     1   A   4  20  ...  11
# 193  Ath Madrid     Valencia     3     1   H     1     1   D  14   8  ...  14
# 223     Levante      Osasuna     0     1   A     0     0   D  13   7  ...  10
# 253      Huesca        Celta     3     4   A     2     2   D  19  10  ...  21
# 283     Osasuna       Getafe     0     0   D     0     0   D   4   6  ...  18
#
#      HC  AC  HY  AY  HR  AR  B365H  B365D  B365A
# 13    1  11   2   2   0   0   4.75   3.80   1.72
# ...

# %% [markdown]
# # Nivell 2:
# #### Exercici 2:
#
# Continua amb el conjunt de dades de tema esportiu i genera una mostra estratificada i una mostra utilitzant SMOTE (Synthetic Minority Oversampling Technique).

# %% [markdown]
# **Muestra estratificada**
#
# Miramos la proporción del dataset en relación a una variable categórica, en este caso el resultado FTR, y mantendremos en nuestra muestra la misma proporción.

# %%
#FTR es el resultado del partido (H=Home Win, D=Draw, A=Away Win)
# Proporción de valores
df.FTR.value_counts(normalize=True)
# Out:
# H    0.403333
# D    0.300000
# A    0.296667
# Name: FTR, dtype: float64

# %% [markdown]
# **Nuestra muestra tendrá 4H, 3D y 3A**

# %%
from sklearn.model_selection import train_test_split

# %%
y=df.FTR
train,test=train_test_split(df,stratify=y, test_size=10)

# %%
test
# Out:
#        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  AF  \
# 223     Levante     Osasuna     0     1   A     0     0   D  13   7  ...  10
# 284      Alaves       Celta     1     3   A     0     3   A  17   8  ...  21
# 8        Getafe     Osasuna     1     0   H     0     0   D   7  10  ...  13
# 250       Elche     Sevilla     2     1   H     0     0   D   6  11  ...  11
# 50       Alaves       Elche     0     2   A     0     1   A  13   7  ...  11
# 127   Barcelona    Valencia     2     2   D     1     1   D  25  12  ...  14
# 145     Sevilla  Villarreal     2     0   H     1     0   H  10   6  ...  14
# 93   Valladolid     Levante     1     1   D     0     0   D  10  10  ...  11
# 70      Granada     Levante     1     1   D     1     1   D   5  19  ...  14
# 269     Sevilla       Elche     2     0   H     1     0   H  13  11  ...   8
#
#      HC  AC  HY  AY  HR  AR  B365H  B365D  B365A
# 223   2   1   1   2   0   0   2.25   3.20   3.40
# ...

# %%
test.FTR.value_counts()
# Out:
# H    4
# A    3
# D    3
# Name: FTR, dtype: int64

# %% [markdown]
# **Se cumple la proporción en la muestra**

# %% [markdown]
# **SMOTE (Synthetic Minority Oversampling Technique)**
#
# En este caso nuestro dataset está balanceado por lo que aplicar SMOTE no sería necesaria. Vamos a realizarla para ver como se generan nuevas muestras (oversampling) y como las proporciones en las tres categorías de FTR se igualan

# %%
#Eliminamos las columnas con los nombres de los equipos y convertimos en one-hot la variable categórica HTR
X1=df.drop(['FTR','HomeTeam','AwayTeam'],'columns')
X1=pd.get_dummies(X1,columns=['HTR'], drop_first=True)
y=df.FTR
X1.head()
# Out:
#    FTHG  FTAG  HTHG  HTAG  HS  AS  HST  AST  HF  AF  ...  AC  HY  AY  HR  AR  \
# 0     0     0     0     0   8   6    1    3  17  13  ...   3   4   4   1   0
# 1     2     0     0     0   4   9    2    2   8  10  ...   2   3   4   0   0
# 2     0     2     0     1  12   6    3    4  14  21  ...   2   2   2   0   0
# 3     0     1     0     0   7  11    2    4  19  17  ...   4   3   3   0   0
# 4     1     1     1     0   8   8    3    2  15  17  ...   3   4   1   0   0
#
#    B365H  B365D  B365A  HTR_D  HTR_H
# 0   2.50   3.25   2.90      1      0
# 1   2.75   3.10   2.75      1      0
# 2   2.80   3.00   2.75      0      0
# 3   2.80   3.20   2.60      1      0
# 4   2.80   3.20   2.60      0      1
#
# [5 rows x 21 columns]

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_sm, y_sm = sm.fit_resample(X1, y)

# %% [markdown]
# **Ahora las tres clases están proporcionadas y ha aumentado el número de muestras en el dataset en 63 muestras más**

# %%
y_sm.value_counts(normalize=True)
# Out:
# D    0.333333
# H    0.333333
# A    0.333333
# Name: FTR, dtype: float64

# %%
X_sm.shape[0]
# Out:
# 363

# %% [markdown]
# Ahora podemos estratificar y obtener la muestra

# %%
X_train,X_test,y_train,y_test=train_test_split(X_sm,y_sm,stratify=y_sm, test_size=12)

# %%
df_smote=pd.concat([X_test,y_test], axis=1)
df_smote
# Out:
#      FTHG  FTAG  HTHG  HTAG  HS  AS  HST  AST  HF  AF  ...  HY  AY  HR  AR  \
# 321     0     3     0     2  12  12    2    6  13  12  ...   2   2   0   0
# 53      2     1     2     0   3  14    2    4  15   8  ...   3   2   0   0
# 311     0     1     0     0  12   6    4    2  12  10  ...   1   2   0   0
# 192     1     1     1     0   7   9    4    2  10  16  ...   4   3   0   0
# 248     2     1     0     1  25  10    4    5  12  10  ...   4   3   0   0
# 129     1     3     0     2   6  13    1    6  17  16  ...   2   2   1   0
# 227     1     0     0     0  12   6    5    1  17  18  ...   5   4   1   0
# 330     1     3     0     0  13  12    5    4   9  12  ...   4   2   0   0
# 101     1     1     1     1   8  10    4    2  18  12  ...   5   3   0   0
# 135     2     2     0     1   7  15    2    6   8  17  ...   1   2   0   1
# 350     1     1     0     1  11   6    2    2  15  21  ...   1   3   0   0
# ...

# %%
df_smote.FTR.value_counts()
# Out:
# A    4
# H    4
# D    4
# Name: FTR, dtype: int64

# %% [markdown]
# En este caso hemos cogido 12 muestras en vez de 10 para mostrar que las proporciones se igualan ya que 10 no es divisible por 3. Para 10 muestras una clase deberá tener una muestra más y no veríamos el efecto de SMOTE.

# %% [markdown]
# # Nivell 3:
# #### Exercici 3:
# Continua amb el conjunt de dades de tema esportiu i genera una mostra utilitzant el mètode Reservoir sampling.

# %% [markdown]
# **Veamos que funciona el algoritmo de reservoir**
#
# Queremos que la probabilidad de cada elemento sea uniforme 1/n

# %%
def reservoir(lista,n,k):
    samples =[]
    #asignamos los primeros k elementos
    for i in range(k):
        samples.append(lista[i])
    # y ahora van entrando nuevos elementos
    for j in range(k,n):
        # Generamos un número aleatorio entre los j numeros
        # así estamos cumpliendo que la probabilidad sea 1/j
        index = random.randint(0, j)        
        if index < k:
            samples[index] = lista[j]
    return samples

# %% [markdown]
# Si n=5 la probabilidad de cada elemento debe ser 1/5=0.2. **Vamos a comprobarlo!!!**
#
# Repetimos el proceso 1000 veces

# %%
lista=[1,2,3,4,5]
# m repeticiones
m=1000
lista_samples=[]
for i in range(m):
    # cogemos muestras de 4 elementos y un stream de n
    sample=reservoir(lista,5,4)
    lista_samples.append(sample)
#contamos 
lista=[j for i in lista_samples for j in i]
dict={i:lista.count(i) for i in lista}
dict
# Out:
# {1: 805, 5: 813, 3: 797, 4: 780, 2: 805}

# %%
plt.bar(dict.keys(),dict.values())
plt.xlabel('valores lista')
plt.ylabel('#')
plt.title('# repeticiones')
plt.show()

# %%
lista=list(dict.values())
#probabilidades (#casos probables/#casos totales)
np.array(lista)/sum(lista)
# Out:
# array([0.20125, 0.20325, 0.19925, 0.195  , 0.20125])

# %% [markdown]
# Vemos por el gráfico que es una distribución uniforme, las repeticiones se reparten por igual, a continuación calculamos la probabilidad de cada elemento de la lista y vemos que se acerca a 0.20

# %% [markdown]
# Ahora para nuestro dataframe trabajaremos solo con su índice y filtraremos por la muestra obtenida

# %%
lista=df.index.tolist()
n=len(lista) #300 elementos
k=10         #10 elementos por muestra
sample=reservoir(lista,n,k)
sample
# Out:
# [141, 228, 176, 142, 39, 30, 73, 279, 37, 85]

# %%
df.iloc[sample,:]
# Out:
#         HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  AS  ...  \
# 141       Getafe        Celta     1     1   D     1     1   D   6   2  ...
# 228        Elche        Eibar     1     0   H     1     0   H   6  13  ...
# 176   Ath Madrid      Sevilla     2     0   H     1     0   H   5  13  ...
# 142  Real Madrid      Granada     2     0   H     0     0   D  23  10  ...
# 39        Alaves   Ath Bilbao     1     0   H     0     0   D   8   8  ...
# 30    Ath Bilbao        Cadiz     0     1   A     0     0   D  13   3  ...
# 73         Elche        Celta     1     1   D     1     1   D   8  14  ...
# 279     Sociedad    Barcelona     1     6   A     0     2   A  10  14  ...
# 37      Valencia        Betis     0     2   A     0     1   A   5  17  ...
# 85    Villarreal  Real Madrid     1     1   D     0     1   A  13   6  ...
#
#      AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A
# 141  16   1   4   3   3   0   0   2.75   3.00   2.80
# ...
